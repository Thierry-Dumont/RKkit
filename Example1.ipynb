# %% [markdown]
# # Playing with Runge-Kutta methods ##

# %%
from RKformula import *
from RKplot import *
from RKcolloc import *
from RKplot import *

# %% [markdown]
# Let us import somme Runge-Kutta method descriptions:

# %%
load("lobatto4.sage","radau5.sage","sdirk3.sage","gauss4.sage","radau2a.sage","rk4.sage","sdirk5.sage")

# %% [markdown]
# Choose one formula:

# %%
RK=Radau5

# %% [markdown]
# and define the computing tool:

# %%
F=RKformula(RK.A,RK.B)

# %% [markdown]
# Ok, now let-us check different properties of the formula:

# %%
F.is_A_stable()
# Out:
# True

# %%
F.is_L_stable()
# Out:
# True

# %%
F.is_stiffly_accurate()
# Out:
# True

# %%
# %display latex
F.stability_function()
# Out:
# (0.05000000000000000?*z^2 + 0.4000000000000000?*z + 1)/(-0.01666666666666667?*z^3 + 0.1500000000000000?*z^2 - 0.6000000000000000?*z + 1)

# %%
F.order_of_stability_function()
# Out:
# 5

# %%
F.order_using_rooted_trees()
# Out:
# 5

# %% [markdown]
# Now, let-us draw the limite of the stability domain:

# %%
p=RKplot(F,fill=False,ncurves=20,limits=[(-5,+15),(-10,10)])

# %%
p.show()
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# We can also draw the order star:

# %%
p=RKplot(F,fill=False,ncurves=10,type="star",limits=[(-5,+6),(-10,10)])
p.show()
# Out:
# Graphics object consisting of 1 graphics primitive
